# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 30.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 17.4 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI


if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your goggle api key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature = 0.0)
# Out:
# Enter your goggle api key: ··········

# %%
task = "Write  a rejection email to a candidate."

print("---lazy prompt---")
print(llm.invoke(task).content)
# Out:
# ---lazy prompt---
# Here are a few options for a rejection email, ranging from standard to slightly more encouraging. Choose the one that best fits your company culture and the specific situation.
#
# **Key Principles for Rejection Emails:**
#
# *   **Be Prompt:** Don't leave candidates hanging.
# *   **Be Clear:** State directly that they were not selected.
# *   **Be Professional and Polite:** Thank them for their time and interest.
# *   **Be Concise:** Get to the point without unnecessary detail.
# *   **Avoid Specific Feedback (Generally):** Unless you have a very structured and positive feedback process, avoid giving specific reasons for rejection, as it can open the door to debate or legal issues. General reasons like "highly competitive pool" are usually sufficient.
# *   **Maintain a Positive Company Image:** Leave the candidate with a good impression of your company, even if they weren't hired.
#
# ---
#
# **Option 1: Standard & Concise**
#
# **Subject: Update on Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your interest in the [Job Title] position at [Company Name] and for taking the time to interview with our team. We appreciate you sharing your experience and qualifications with us.
#
# We received a large number of highly qualified applications for this role, and after careful consideration, we have decided to move forward with other candidates whose qualifications and experience were a closer match for our current needs.
#
# This was a very competitive process, and we truly appreciate your time and effort.
#
# We wish you the best of luck in your job search and future endeavors.
#
# Sincerely,
#
# The [Company Name] Hiring Team
# [Your Name, if applicable]
# [Your Title, if applicable]
#
# ---
#
# **Option 2: Slightly More Encouraging (if you might consider them for future roles)**
#
# **Subject: Regarding Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your application for the [Job Title] position at [Company Name] and for taking the time to speak with us about your background and interest in the role. We enjoyed learning more about your skills and experience.
#
# We had many strong applicants, and the decision was a difficult one. While your qualifications are impressive, we have decided to move forward with another candidate whose experience was a more precise fit for the specific requirements of this particular role at this time.
#
# We encourage you to keep an eye on our careers page at [Link to Careers Page, if applicable] for future openings that may align with your skills and career goals.
#
# Thank you again for your interest in [Company Name]. We wish you all the best in your job search.
#
# Sincerely,
#
# [Your Name]
# [Your Title]
# [Company Name]
#
# ---
#
# **Option 3: For a candidate who only submitted an application (no interview)**
#
# **Subject: Your Application for [Job Title] at [Company Name]**
#
# Dear [Candidate Name],
#
# Thank you for your interest in the [Job Title] position at [Company Name] and for submitting your application. We appreciate you taking the time to share your qualifications with us.
#
# We received a significant number of applications for this role, and after careful review, we have decided to move forward with other candidates whose profiles were a closer match for the specific requirements of the position.
#
# We wish you the best of luck in your job search and future career.
#
# Sincerely,
#
# The [Company Name] Hiring Team
#
# ---
#
# **Before Sending:**
#
# *   **Personalize:** Always use the candidate's name and the correct job title.
# *   **Proofread:** Double-check for any typos or grammatical errors.
# *   **Consistency:** Ensure the tone aligns with your company's brand.

# %%
structured_prompt = """
# Context
You are an HR Manager at a quirky startup called 'RocketBoots'.

# Objective
Write a rejection email to a candidate named Bob.

# Constraints
1. Be extremely brief (under 50 words).
2. Do NOT say 'we found someone better'. Say 'the role changed'.
3. Sign off with 'Keep flying'.

# Output Format
Plain text, no subject line.
"""

print("--- STRUCTURED PROMPT ---")
print(llm.invoke(structured_prompt).content)
# Out:
# --- STRUCTURED PROMPT ---
# Hi Bob,
#
# Thank you for your interest in RocketBoots.
#
# We appreciate you taking the time to interview. However, the role's requirements have changed significantly since your application. We wish you the best in your job search.
#
# Keep flying.

# %% [markdown]
# ASSIGNMENT

# %%
structured_prompt = """
# Context
You are a Senior Python Developer with expertise in writing clean, efficient, and production-quality code.

# Objective
Write a Python function to reverse a string.

# Constraints
1. The function MUST use recursion.
2. DO NOT use slicing (e.g., [::-1]).
3. DO NOT use built-in reverse functions.
4. Ensure the solution is efficient and correct.

# Style
Include a detailed docstring explaining:
- Purpose of the function
- Parameters
- Return value
- How recursion works in this function
- Example usage

# Audience
The code is intended for beginner to intermediate Python developers.

# Response Format
Output only valid Python code with the function definition and docstring.
"""
print(llm.invoke(structured_prompt).content)
# Out:
# ```python
# def reverse_string_recursive(s: str) -> str:
#     """
#     Recursively reverses a given string without using slicing for reversal (e.g., [::-1])
#     or built-in reverse functions.
#
#     This function demonstrates a classic recursive approach to string reversal,
#     breaking down the problem into smaller, identical subproblems until a base
#     case is reached. It is designed to be clear and illustrative of recursive
#     thinking.
#
#     Parameters:
#         s (str): The input string to be reversed.
#
#     Returns:
#         str: The reversed version of the input string.
#
#     How Recursion Works:
#         The core idea is to reverse the "tail" of the string and then append
#         the "head" character to it. This process continues until the string
#         is too short to be broken down further.
#
#         1.  **Base Case**: The recursion stops when the input string `s` is
#             either empty (`""`) or contains only a single character (e.g., `"a"`).
#             In these cases, the string is already considered reversed, so the
#             function simply returns `s` itself. This is crucial to prevent
#             infinite recursion.
#
#         2.  **Recursive Step**: If the string `s` has two or more characters:
#             -   The function identifies the *first character* of `s` (which is `s[0]`).
#             -   It then makes a recursive call to `reverse_string_recursive`
#                 with the *rest of the string* (`s[1:]`). This call will return
#                 the reversed version of the substring from the second character
#                 to the end.
#             -   Finally, it concatenates the result of this recursive call (the
#                 reversed "tail") with the *first character* (`s[0]`). By appending
#                 the first character to the *end* of the reversed tail, it effectively
#                 moves that character to its correct reversed position.
#
#         Example Trace for "abc":
#         -   `reverse_string_recursive("abc")`
#             -   `s[0]` is 'a'
#             -   `s[1:]` is "bc"
#             -   Calls `reverse_string_recursive("bc")`
#                 -   `s[0]` is 'b'
#                 -   `s[1:]` is "c"
#                 -   Calls `reverse_string_recursive("c")`
#                     -   Base case: length is 1. Returns "c".
#                 -   Returns "c" + 'b' -> "cb"
#             -   Returns "cb" + 'a' -> "cba"
#
#     Example Usage:
#         >>> reverse_string_recursive("hello")
#         'olleh'
#         >>> reverse_string_recursive("Python")
#         'nohtyP'
#         >>> reverse_string_recursive("")
#         ''
#         >>> reverse_string_recursive("a")
#         'a'
#         >>> reverse_string_recursive("racecar")
#         'racecar'
#     """
#     # Base case: If the string is empty or has only one character, it's already reversed.
#     if len(s) <= 1:
#         return s
#     # Recursive step:
#     # 1. Take the first character (s[0]).
#     # 2. Recursively reverse the rest of the string (s[1:]).
#     # 3. Concatenate the reversed rest of the string with the first character.
#     return reverse_string_recursive(s[1:]) + s[0]
# ```

# %%
# Setup
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.5)

# %%
prompt_zero = "Combine 'Angry' and 'Hungry' into a funny new word."
print(f"Zero-Shot: {llm.invoke(prompt_zero).content}")
# Out:
# Zero-Shot: The most common and widely accepted funny word for this is **Hangry**.

# %%
prompt_few = """
Combine words into a funny new word. Give a sarcastic definition.

Input: Breakfast + Lunch
Output: Brunch (An excuse to drink alcohol before noon)

Input: Chill + Relax
Output: Chillax (What annoying people say when you are panic attacks)

Input: Angry + Hungry
Output:
"""
print(f"Few-Shot: {llm.invoke(prompt_few).content}")
# Out:
# Few-Shot: Output: Hangry (A completely legitimate medical condition that justifies all rude behavior until a snack is provided.)

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google API Key: ")
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate

# 1. Our Database of Examples
examples = [
    {"input": "The internet is down.", "output": "We are observing connectivity latency."},
    {"input": "This code implies a bug.", "output": "The logic suggests unintended behavior."},
    {"input": "I hate this feature.", "output": "This feature does not align with my preferences."},
]

# 2. Template for ONE example
example_fmt = ChatPromptTemplate.from_messages([
    ("human", "{input}"),
    ("ai", "{output}")
])

# 3. The Few-Shot Container
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_fmt,
    examples=examples
)

# 4. The Final Chain
final_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a Corpo-Speak Translator. Rewrite the input to sound professional."),
    few_shot_prompt,      # Inject examples here
    ("human", "{text}")
])

chain = final_prompt | llm

print(chain.invoke({"text": "This app sucks."}).content)
# Out:
# The application presents opportunities for enhancement.
