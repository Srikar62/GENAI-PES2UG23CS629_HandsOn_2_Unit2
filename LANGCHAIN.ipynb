# %%
# %pip install python-dotenv --upgrade --quiet langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 8.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 500.5/500.5 kB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 18.1 MB/s eta 0:00:00

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your goggle api key: ")
# Out:
# Enter your goggle api key: ··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

#model A the acoutant (precision)
llm_focused = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0.0)

#model B the poet
llm_creative  = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=1.0)

# %%
prompt = "Define the word 'Idea' in one sentence"

print("----FOCUSSED (temp=0)----")
print(f"run 1:{llm_focused.invoke(prompt).content}")
print(f"run 2:{llm_focused.invoke(prompt).content}")
# Out:
# ----FOCUSSED (temp=0)----
# run 1:An idea is a mental construct, such as a thought, concept, or plan, that forms in the mind.
# run 2:An idea is a mental construct, such as a thought, concept, or plan, that forms in the mind.

# %%
print("----CREATIVE (temp=1)----")
print(f"run 1:{llm_creative.invoke(prompt).content}")
print(f"run 2:{llm_creative.invoke(prompt).content}")
# Out:
# ----CREATIVE (temp=1)----
# run 1:An idea is a concept, plan, or mental image formed in the mind as a product of thought.
# run 2:An idea is a thought, concept, or plan that originates in the mind, often serving as a suggestion, solution, or understanding.

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your goggle api key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
from langchain_core.messages import SystemMessage, HumanMessage

messages = [
    SystemMessage(content="me and my friend discussing about capitals of countries"),
    HumanMessage(content="What is capital of INDIA?")
]
Reponse = llm.invoke(messages)
print(Reponse.content)
# Out:
# The capital of India is **New Delhi**.

# %%
from dotenv import load_dotenv
load_dotenv()

import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

if "GOOGLE_API_KEY" not in os.environ:
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your goggle api key: ")

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template("Tell me a fun fact about {topic}.")
parser = StrOutputParser()

# %%
prompt_value = template.invoke({"topic":"anime"})

response_obj = llm.invoke(prompt_value)

final_text = parser.invoke(response_obj)

print(final_text)
# Out:
# Here's a fun one:
#
# In Japan, the voice actors for anime characters, known as **seiyuu**, are often massive celebrities themselves! They're not just voices; many of them are also pop idols, singers, models, and even live-action actors.
#
# It's very common for a seiyuu who voices a main character in an anime to also sing the opening or ending theme song for that very show, release character albums, and perform in huge concerts for their fans. They have dedicated fan bases just like rock stars!

# %%
chain = template | llm | parser

print(chain.invoke({"topic":"anime"}))
# Out:
# Here's a fun one:
#
# Did you know that the longest-running animated TV series *in the world* is an anime called **Sazae-san**? It first aired in 1969 and has over **8,000 episodes** (and is still going strong!) – that's more episodes than *The Simpsons* and *Dragon Ball Z* combined, many times over!

# %% [markdown]
# ASSIGNMENT

# %%
from dotenv import load_dotenv
import os
import getpass

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Load API key
load_dotenv()

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key: ")

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
template = ChatPromptTemplate.from_template(
    "The movie '{movie}' was released in which year? Also calculate how many years ago that was from 2026."
)
parser = StrOutputParser()
chain = template | llm | parser
result = chain.invoke({"movie": "Bahubali: The Beginning"})
print(result)
# Out:
# The movie 'Bahubali: The Beginning' was released in **2015**.
#
# From 2026, that was **11 years ago** (2026 - 2015 = 11).
